# %% [markdown]
# <a href="https://colab.research.google.com/github/bibekebib/Major-project-raw-files/blob/main/__init__(self%2C_args).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = '/content/drive/MyDrive/dataset'

# %%
from glob import glob
import pandas as pd

# %%
glob(dataset_path+'/*')
# Out:
# ['/content/drive/MyDrive/dataset/vriksh',
#  '/content/drive/MyDrive/dataset/bhujan',
#  '/content/drive/MyDrive/dataset/tadasana',
#  '/content/drive/MyDrive/dataset/trik',
#  '/content/drive/MyDrive/dataset/padmasan',
#  '/content/drive/MyDrive/dataset/shav',
#  '/content/drive/MyDrive/dataset/dataset.csv']

# %%
# len(glob(dataset_path+'/*/*.mp4'))

# %%
# all = [x for x in glob(dataset_path+'/*/*.mp4').]

# %%
# label = []
# path = []
# for i in all:
#    label.append(i.split('/')[-2])
#    path.append(i)

# %%
# # df = pd.DataFrame()
# data = []
# data.append(path)
# data.append(label)
# df = pd.DataFrame(data).transpose()
# df.columns=['Path','Label']

# %%
df = pd.read_csv(dataset_path+'/dataset.csv')

# %%
# df = df.sample(frac=1).reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Path', 'Label'], dtype='object')

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# df.to_csv('dataframe.csv')

# %%
df.head()
# Out:
#                                                 Path     Label
# 0  /content/drive/MyDrive/dataset/vriksh/veena_vr...    vriksh
# 1  /content/drive/MyDrive/dataset/bhujan/Ameya_Bh...    bhujan
# 2  /content/drive/MyDrive/dataset/vriksh/Kaustuk_...    vriksh
# 3  /content/drive/MyDrive/dataset/tadasana/Shiva_...  tadasana
# 4  /content/drive/MyDrive/dataset/shav/Veena_Shav...      shav

# %%
df.Path[0]
# Out:
# '/content/drive/MyDrive/dataset/vriksh/veena_vriksh.mp4'

# %%
import seaborn as sns
sns.countplot(df.Label)
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Read frame number 53 of each video:
frame_number=93 #random
import cv2
def showFrame(path):
    cap = cv2.VideoCapture(path)
    cap.set(1, frame_number)
    res, frame = cap.read()
    print(f'Before conversion to grayscale {frame.shape}')
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    print(f'afer conversion to grayscale {frame.shape} ')
    plt.imshow(frame[30:700,200:1050])
    plt.title(path.split('/')[-2])
    plt.axis(False)
    plt.show()

# %%
showFrame(df.Path[2])
# Out:
# Before conversion to grayscale (768, 1366, 3)
# afer conversion to grayscale (768, 1366)

# %%
poses = ['vriksh', 'bhujan', 'tadasana', 'shav', 'padmasan', 'trik']

# %%
indexs = []
# print(df.loc[df['Label']=='vriksh'])
for i in range(len(poses)):
  indexs.append((df.loc[df['Label']==poses[i]]))

# %%
psycho = []
for i in range(len(indexs)):
  psycho.append((((indexs[i].Path).tolist())[0]))

# %%
psycho
# Out:
# ['/content/drive/MyDrive/dataset/vriksh/veena_vriksh.mp4',
#  '/content/drive/MyDrive/dataset/bhujan/Ameya_Bhuj.mp4',
#  '/content/drive/MyDrive/dataset/tadasana/Shiva_Tadasana.mp4',
#  '/content/drive/MyDrive/dataset/shav/Veena_Shav.mp4',
#  '/content/drive/MyDrive/dataset/padmasan/Piyush_Padam.mp4',
#  '/content/drive/MyDrive/dataset/trik/Shiva_Trik.mp4']

# %%
for i in psycho:
  showFrame(i)
# Out:
# Before conversion to grayscale (768, 1366, 3)
# afer conversion to grayscale (768, 1366)
# Before conversion to grayscale (768, 1366, 3)
# afer conversion to grayscale (768, 1366)
# Before conversion to grayscale (768, 1366, 3)
# afer conversion to grayscale (768, 1366)
# Before conversion to grayscale (768, 1366, 3)
# afer conversion to grayscale (768, 1366)
# Before conversion to grayscale (768, 1366, 3)
# afer conversion to grayscale (768, 1366)
# Before conversion to grayscale (768, 1366, 3)
# afer conversion to grayscale (768, 1366)

# %%
df.Path[0]
# Out:
# '/content/drive/MyDrive/dataset/vriksh/veena_vriksh.mp4'

# %%
number = []
def count_frames(path):
  cap = cv2.VideoCapture(path)
  number.append((path.split('/')[-2], int(cap.get(cv2.CAP_PROP_FRAME_COUNT))))

# %%
for x in df.Path:
  count_frames(x)

# %%
frame_number = pd.DataFrame(number)

# %%
frame_number.to_csv('framecount.csv')

# %%
frame_number.describe()

# %%
import seaborn as sns

# %%
sns.histplot(frame_number[1])
